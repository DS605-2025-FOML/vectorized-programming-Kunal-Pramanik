# %% [markdown]
# # Part 1: NumPy Exercises

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("D:\\ML Lab\\vectorized-programming-Kunal-Pramanik\\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 1. Array Creation and Manipulation:

# %% [markdown]
# >> Load the Age and Fare columns into two separate NumPy arrays, ages and fares.

# %%
ages=df['Age'].to_numpy()
fares=df['Fare'].to_numpy()
ages
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
fares
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#          8.05  ,  31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,
#         18.    ,   7.225 ,  26.    ,  13.    ,   8.0292,  35.5   ,
#         21.075 ,  31.3875,   7.225 , 263.    ,   7.8792,   7.8958,
#         27.7208, 146.5208,   7.75  ,  10.5   ,  82.1708,  52.    ,
#          7.2292,   8.05  ,  18.    ,  11.2417,   9.475 ,  21.    ,
#          7.8958,  41.5792,   7.8792,   8.05  ,  15.5   ,   7.75  ,
#         21.6792,  17.8   ,  39.6875,   7.8   ,  76.7292,  26.    ,
#         61.9792,  35.5   ,  10.5   ,   7.2292,  27.75  ,  46.9   ,
#          7.2292,  80.    ,  83.475 ,  27.9   ,  27.7208,  15.2458,
#         10.5   ,   8.1583,   7.925 ,   8.6625,  10.5   ,  46.9   ,
#         73.5   ,  14.4542,  56.4958,   7.65  ,   7.8958,   8.05  ,
#         29.    ,  12.475 ,   9.    ,   9.5   ,   7.7875,  47.1   ,
# ...

# %% [markdown]
# >> The ages array has missing values (NaN). Create a new array cleaned_ages where all NaN
#     values are replaced with the median age of the passengers

# %%
median_age = np.nanmedian(ages)       # take median while ignoring NaNs
median_age
# Out:
# np.float64(28.0)

# %%
cleaned_ages = np.where(np.isnan(ages), median_age, ages)  # replace NaNs with median by where function
cleaned_ages
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 28.  , 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 28.  ,
#        31.  , 28.  , 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  , 28.  ,
#        19.  , 28.  , 28.  , 40.  , 28.  , 28.  , 66.  , 28.  , 42.  ,
#        28.  , 21.  , 18.  , 14.  , 40.  , 27.  , 28.  ,  3.  , 19.  ,
#        28.  , 28.  , 28.  , 28.  , 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  , 28.  , 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  , 28.  , 28.  , 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  , 28.  , 28.  ,  0.83, 30.  , 22.  ,
#        29.  , 28.  , 28.  , 17.  , 33.  , 16.  , 28.  , 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  , 28.  , 71.  , 23.  , 34.  ,
#        34.  , 28.  , 28.  , 21.  , 33.  , 37.  , 28.  , 21.  , 28.  ,
#        38.  , 28.  , 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
#cleaned_ages_int = cleaned_ages.astype(int)  # convert to integer type
#cleaned_ages_int

# %% [markdown]
# >>Create a new array fares_in_euros by converting the fares (which are in British Pounds) to Euros. Assume an exchange rate of 1 Pound = 1.18 Euros.

# %%
fares_in_euros = fares * 1.18
fares_in_euros
# Out:
# array([  8.555   ,  84.114294,   9.3515  ,  62.658   ,   9.499   ,
#          9.980794,  61.19775 ,  24.8685  ,  13.137294,  35.483544,
#         19.706   ,  31.329   ,   9.499   ,  36.9045  ,   9.267956,
#         18.88    ,  34.3675  ,  15.34    ,  21.24    ,   8.5255  ,
#         30.68    ,  15.34    ,   9.474456,  41.89    ,  24.8685  ,
#         37.03725 ,   8.5255  , 310.34    ,   9.297456,   9.317044,
#         32.710544, 172.894544,   9.145   ,  12.39    ,  96.961544,
#         61.36    ,   8.530456,   9.499   ,  21.24    ,  13.265206,
#         11.1805  ,  24.78    ,   9.317044,  49.063456,   9.297456,
#          9.499   ,  18.29    ,   9.145   ,  25.581456,  21.004   ,
#         46.83125 ,   9.204   ,  90.540456,  30.68    ,  73.135456,
#         41.89    ,  12.39    ,   8.530456,  32.745   ,  55.342   ,
#          8.530456,  94.4     ,  98.5005  ,  32.922   ,  32.710544,
#         17.990044,  12.39    ,   9.626794,   9.3515  ,  10.22175 ,
# ...

# %% [markdown]
# ### 2. Statistical Analysis:

# %% [markdown]
# >> Using NumPy, calculate and print the following statistics for the cleaned_ages array:
# ■ Average age
# ■ Standard deviation
# ■ The age of the oldest passenger
# ■ The age of the youngest passenger

# %% [markdown]
# Average age

# %%
avg_cleaned_age = np.mean(cleaned_ages)
avg_cleaned_age
# Out:
# np.float64(29.34567901234568)

# %% [markdown]
# Standard deviation

# %%
sd_cleaned_age = np.std(cleaned_ages)
sd_cleaned_age
# Out:
# np.float64(13.020898804757042)

# %% [markdown]
# The age of oldest passenger

# %%
max_age = np.max(cleaned_ages)
max_age
# Out:
# np.int64(80)

# %%
oldest_passenger = df[df['Age'] == max_age]
oldest_passenger["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %% [markdown]
# The age of Youngest Passenger

# %%
cleaned_ages
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 28.  , 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 28.  ,
#        31.  , 28.  , 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  , 28.  ,
#        19.  , 28.  , 28.  , 40.  , 28.  , 28.  , 66.  , 28.  , 42.  ,
#        28.  , 21.  , 18.  , 14.  , 40.  , 27.  , 28.  ,  3.  , 19.  ,
#        28.  , 28.  , 28.  , 28.  , 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  , 28.  , 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  , 28.  , 28.  , 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  , 28.  , 28.  ,  0.83, 30.  , 22.  ,
#        29.  , 28.  , 28.  , 17.  , 33.  , 16.  , 28.  , 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  , 28.  , 71.  , 23.  , 34.  ,
#        34.  , 28.  , 28.  , 21.  , 33.  , 37.  , 28.  , 21.  , 28.  ,
#        38.  , 28.  , 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...

# %%
min_age = np.min(cleaned_ages)
min_age
# Out:
# np.float64(0.42)

# %%
youngest_passenger = df[df['Age'] == min_age]
youngest_passenger["Name"]
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %% [markdown]
# ### 3. Boolean Indexing and Filtering:

# %% [markdown]
# >>  Create a boolean array that is True for passengers who paid a Fare greater than 50 and False
# otherwise.

# %%
fare_above_50 = fares > 50
fare_above_50
# Out:
# array([False,  True, False,  True, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False,  True, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#         True, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
# ...

# %%
high_pay_passengers = df.Name[fare_above_50]
high_pay_passengers
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6                                McCarthy, Mr. Timothy J
# 27                        Fortune, Mr. Charles Alexander
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
#                              ...
# 856           Wick, Mrs. George Dennick (Mary Hitchcock)
# 863                    Sage, Miss. Dorothy Edith "Dolly"
# 867                 Roebling, Mr. Washington Augustus II
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# Name: Name, Length: 160, dtype: object

# %%
df.Name[~fare_above_50]  # names of passengers who paid fare <= 50
# Out:
# 0                       Braund, Mr. Owen Harris
# 2                        Heikkinen, Miss. Laina
# 4                      Allen, Mr. William Henry
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
#                          ...
# 886                       Montvila, Rev. Juozas
# 887                Graham, Miss. Margaret Edith
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 889                       Behr, Mr. Karl Howell
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 731, dtype: object

# %% [markdown]
# >>Use this boolean array to count how many passengers paid more than 50 for their ticket.

# %%
fares[fare_above_50].size
# Out:
# 160

# %%
high_pay_passengers.size
# Out:
# 160

# %% [markdown]
# >>Display the ages of these high-paying passengers.

# %%
ages[fare_above_50]
# Out:
# array([38.  , 35.  , 54.  , 19.  ,   nan, 28.  , 42.  , 49.  , 65.  ,
#        38.  , 45.  , 21.  , 32.  , 23.  , 46.  , 23.  , 21.  , 47.  ,
#        24.  , 21.  , 54.  , 37.  , 24.  , 22.  , 51.  ,   nan,   nan,
#        28.  ,   nan, 58.  ,   nan, 31.  , 32.  , 38.  , 35.  , 44.  ,
#        37.  ,   nan, 30.  , 35.  , 52.  , 58.  , 35.  , 63.  , 26.  ,
#        19.  ,  2.  , 50.  ,  0.92,   nan, 17.  , 30.  , 24.  , 18.  ,
#        31.  , 40.  ,   nan, 36.  , 16.  , 38.  ,   nan, 29.  , 41.  ,
#        24.  , 22.  , 60.  , 24.  , 25.  , 22.  ,   nan, 27.  , 42.  ,
#        35.  , 18.  , 36.  , 23.  , 33.  , 50.  , 14.  , 64.  ,  4.  ,
#        49.  ,   nan,   nan, 25.  , 35.  , 54.  , 25.  , 16.  , 18.  ,
#        26.  , 54.  , 30.  , 44.  ,   nan, 30.  , 36.  , 50.  , 17.  ,
#          nan, 39.  , 53.  , 39.  , 39.  , 18.  , 60.  , 52.  , 49.  ,
#        40.  , 24.  , 42.  , 21.  , 24.  ,   nan, 48.  , 24.  , 58.  ,
# ...

# %%
#cleaned_ages [fare_above_50]

# %% [markdown]
# #

# %% [markdown]
# # Part 2: Pandas Exercises

# %% [markdown]
# #

# %% [markdown]
# ### 1. Data Loading and Initial Exploration:

# %% [markdown]
# >> Load the titanic.csv file into a Pandas DataFrame called df.

# %%
df=pd.read_csv("D:\\ML Lab\\vectorized-programming-Kunal-Pramanik\\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# >>  Display the last 5 rows of the DataFrame.

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# >> Get a summary of the DataFrame's technical information (column names, data types, non-null
# counts).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### 2. Data Cleaning and Preprocessing:

# %% [markdown]
# >> The Cabin column has many missing values. Drop this column entirely from the DataFrame.

# %%
df1 = df.drop(columns=['Cabin'])
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# >>Fill the missing values in the Age column using the mean age.

# %%
df1['Age']=df1['Age'].fillna(df1['Age'].mean())
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# >>The Embarked column has a few missing values. Fill them with the mode (the most common
# port of embarkation).

# %%
mode_embarked = df1['Embarked'].mode()[0] # [0] to get the first mode value as if there was a tie then it gives more than one in series
#mode_embarked
df1['Embarked'] = df1['Embarked'].fillna(mode_embarked)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# >> Confirm that your DataFrame now has no missing values in any of the remaining columns.

# %%
df1_null=df1.isnull()
df1_null.sum() # .sum() is used to get the total count of missing values in each column
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df1_null.values.any()  # to check if there is any NaN value in the entire dataframe
# Out:
# np.False_

# %% [markdown]
# ### 3. Feature Engineering:

# %% [markdown]
# >>Create a new column called FamilySize which is the sum of the SibSp and Parch columns, plus
# 1 (to count the passenger themselves).

# %%
df2=df1.copy()
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2["FamilySize"] = df2["SibSp"] + df2["Parch"] + 1
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# >> Create a categorical column called AgeGroup. Bin the Age column into the following groups:
# ■ Child: 0-12
# ■ Teen: 13-19
# ■ Adult: 20-59
# ■ Senior: 60+

# %%
bins=[0,12,19,59,np.inf]
labels=['Child','Teen','Adult','Senior']
df2['AgeGroup'] = pd.cut(df2['Age'], bins=bins, labels=labels, right=True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ### 4. Data Selection and Querying:

# %% [markdown]
# >>Display the Name, Sex, and AgeGroup of all passengers who survived.

# %%
survivors=df2[df2['Survived']==1]
survivors
survivors[['Name', 'Sex', 'AgeGroup']]
# Out:
#                                                   Name     Sex AgeGroup
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    Adult
# 2                               Heikkinen, Miss. Laina  female    Adult
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female    Adult
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female    Adult
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female     Teen
# ..                                                 ...     ...      ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female     Teen
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female    Adult
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female    Adult
# 887                       Graham, Miss. Margaret Edith  female     Teen
# 889                              Behr, Mr. Karl Howell    male    Adult
#
# [342 rows x 3 columns]

# %% [markdown]
# >>Find all female passengers who were in 1st Class (Pclass == 1).

# %%
female_1st_class=df2[(df2['Sex']=='female') & (df2['Pclass']==1)]
female_1st_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 11                            Bonnell, Miss. Elizabeth  female  58.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  29.699118
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
# ..                                                 ...     ...        ...
# ...

# %%
female_1st_class['Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 11                              Bonnell, Miss. Elizabeth
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)
#                              ...
# 856           Wick, Mrs. George Dennick (Mary Hitchcock)
# 862    Swift, Mrs. Frederick Joel (Margaret Welles Ba...
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887                         Graham, Miss. Margaret Edith
# Name: Name, Length: 94, dtype: object

# %% [markdown]
# >>Select all passengers who embarked from Southampton ('S') and paid a fare less than 10.

# %%
df2[(df2['Embarked']=='S') & (df2['Fare']<10)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0              1         0       3               Braund, Mr. Owen Harris
# 2              3         1       3                Heikkinen, Miss. Laina
# 4              5         0       3              Allen, Mr. William Henry
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 876          877         0       3         Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                  Petroff, Mr. Nedelio
# 878          879         0       3                    Laleff, Mr. Kristo
# 881          882         0       3                    Markun, Mr. Johann
# 884          885         0       3                Sutehall, Mr. Henry Jr
#
#         Sex        Age  SibSp  Parch            Ticket    Fare Embarked  \
# ...

# %% [markdown]
# ### 5. Grouping and Aggregation (Groupby):

# %% [markdown]
# >>What was the average age of passengers who survived versus those who did not? (Hint: Group
# by the Survived column).

# %%
avg_age_gb=df2.groupby('Survived')['Age'].mean()
avg_age_gb
# Out:
# Survived
# 0    30.415100
# 1    28.549778
# Name: Age, dtype: float64

# %% [markdown]
# >>Group the DataFrame by Pclass and Sex. For each group, calculate the survival rate (the mean
# of the Survived column). This will show you the survival probability for men and women in
# each class

# %%
survival_rate=df2.groupby(['Pclass','Sex'])['Survived'].mean()

# %%
survival_rate
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %% [markdown]
# ### 6. Exporting the Final DataFrame:

# %% [markdown]
# >>Save your final, cleaned DataFrame with the new FamilySize and AgeGroup columns to a new
# CSV file named titanic_processed.csv. Do not include the pandas index in the file.

# %%
df2.to_csv("titanic_processed.csv", index=False)
